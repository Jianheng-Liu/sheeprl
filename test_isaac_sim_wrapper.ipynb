# %%
from sheeprl.envs.isaacsim import IsaacSimWrapper
wrapped_env = IsaacSimWrapper()

obs = wrapped_env.reset()
print("Initial Observation:", obs)
obs, reward, done, truncated, info = wrapped_env.step(0)
print("Step Observation:", obs)
# Out:
# Initial Observation: ({'position': array([5.24591707, 8.21261949]), 'local_map': array([[[ 74],
#         [220],
#         [198],
#         ...,
#         [177],
#         [ 33],
#         [ 90]],
#
#        [[230],
#         [101],
#         [133],
#         ...,
#         [ 44],
#         [233],
#         [ 94]],
#
#        [[213],
#         [  5],
#         [ 47],
#         ...,
#         [189],
#         [166],
#         [ 68]],
#
#        ...,
#
#        [[ 20],
#         [109],
#         [ 74],
#         ...,
#         [107],
#         [191],
#         [202]],
#
#        [[ 53],
#         [ 28],
#         [185],
#         ...,
#         [ 19],
#         [217],
#         [209]],
#
#        [[227],
#         [  1],
#         [182],
#         ...,
#         [ 77],
#         [164],
#         [159]]], dtype=uint8), 'rgb_image': array([[[188, 204,   6],
#         [182, 184,  55],
#         [167,  36,  15],
#         ...,
#         [233, 239,  31],
#         [101,  50, 143],
#         [114, 231, 173]],
#
#        [[159, 199,  54],
#         [139,  20,  46],
#         [ 94, 210, 211],
#         ...,
#         [229,  27, 206],
#         [194,  59, 190],
#         [189, 199, 222]],
#
#        [[232, 105, 138],
#         [171, 149, 106],
#         [ 25, 165, 170],
#         ...,
#         [165,   5, 179],
#         [ 46, 224,  38],
#         [115, 124,  83]],
#
#        ...,
#
#        [[143, 170,  37],
#         [ 60, 124,  85],
#         [203, 160, 167],
#         ...,
#         [255,  11, 255],
#         [ 87,  94, 116],
#         [ 82,  56, 253]],
#
#        [[ 47,  52,  61],
#         [102, 237,  61],
#         [253, 115, 123],
#         ...,
#         [110, 169, 227],
#         [134, 163, 200],
#         [121, 151, 143]],
#
#        [[ 89, 100,   6],
#         [127, 248,  29],
#         [197,  79,   2],
#         ...,
#         [100,   9, 145],
#         [ 20,  28,  23],
#         [ 23, 216,  34]]], dtype=uint8)}, {})
# Step Observation: {'position': array([9.79856843, 9.56152073]), 'local_map': array([[[ 30],
#         [173],
#         [ 65],
#         ...,
#         [253],
#         [174],
#         [158]],
#
#        [[112],
#         [228],
#         [163],
#         ...,
#         [149],
#         [184],
#         [230]],
#
#        [[112],
#         [ 77],
#         [103],
#         ...,
#         [ 94],
#         [200],
#         [ 32]],
#
#        ...,
#
#        [[ 70],
#         [ 80],
#         [109],
#         ...,
#         [ 25],
#         [ 28],
#         [ 72]],
#
#        [[196],
#         [ 72],
#         [ 81],
#         ...,
#         [160],
#         [112],
#         [215]],
#
#        [[110],
#         [ 34],
#         [235],
#         ...,
#         [  2],
#         [232],
#         [ 68]]], dtype=uint8), 'rgb_image': array([[[ 50, 186, 116],
#         [254, 182, 233],
#         [146, 102, 223],
#         ...,
#         [ 57,  99,  95],
#         [111, 138,  10],
#         [208, 113,   8]],
#
#        [[176, 232,  17],
#         [164, 237, 169],
#         [ 46, 129, 104],
#         ...,
#         [215,  39, 244],
#         [204,   5,  64],
#         [ 56,  60,   3]],
#
#        [[ 86,  85,  84],
#         [181, 220,  79],
#         [ 74, 188,   7],
#         ...,
#         [135,  62,  34],
#         [ 77, 199, 179],
#         [ 25, 122, 161]],
#
#        ...,
#
#        [[197, 157, 212],
#         [199, 103,  47],
#         [241, 216, 108],
#         ...,
#         [150, 211, 103],
#         [203, 242,  46],
#         [180, 185,  16]],
#
#        [[110, 181,  77],
#         [ 71, 131, 178],
#         [230, 204, 146],
#         ...,
#         [191,  40,  27],
#         [ 49, 111, 138],
#         [ 61, 102, 163]],
#
#        [[116, 133,  16],
#         [166, 116,  15],
#         [ 28,  93, 134],
#         ...,
#         [ 11,  47, 244],
#         [236,  99,  90],
#         [136,  21,  50]]], dtype=uint8)}

# %%
# !python sheeprl.py exp=dreamer_v3_isaacsim
# Out:
# Starting kit application with the following args:  ['/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True', '--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=True', '--ext-folder', '/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/exts', '--ext-folder', '/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/apps', '--/physics/cudaDevice=0', '--portable']
# Passing the following args to the base kit application:  ['exp=dreamer_v3_isaacsim']
# [Info] [carb] Logging to file: /home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/kit/logs/Kit/Isaac-Sim/4.0/kit_20240709_141004.log
# 2024-07-09 13:10:04 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [0.040s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.314s] [ext: omni.stats-0.0.0] startup
# [0.314s] [ext: omni.client-1.1.0] startup
# [0.333s] [ext: omni.datastore-0.0.0] startup
# [0.334s] [ext: omni.blobkey-1.1.0] startup
# [0.334s] [ext: omni.ujitso.default-1.0.0] startup
# [0.335s] [ext: omni.hsscclient-0.0.0] startup
# [0.335s] [ext: omni.rtx.shadercache.vulkan-1.0.0] startup
# [0.336s] [ext: omni.assets.plugins-0.0.0] startup
# [0.337s] [ext: omni.gpu_foundation-0.0.0] startup
# [0.346s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.354s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 535.183.01    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24810   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | 25c41863.. |
# |     |                                  |        |     |            | 3e        |            |
# |=============================================================================================|
# | OS: 20.04.6 LTS (Focal Fossa) ubuntu, Version: 20.04.6, Kernel: 5.15.0-113-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12013000 (1.20.13.0)
# | Processor: AMD Ryzen 9 5950X 16-Core Processor | Cores: 16 | Logical: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 64204 | Free Memory: 42083
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 700
# |---------------------------------------------------------------------------------------------|
# 2024-07-09 13:10:05 s] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# [1.087s] [ext: omni.kit.pipapi-0.0.0] startup
# [1.088s] [ext: omni.kit.pip_archive-0.0.0] startup
# [1.088s] [ext: omni.pip.compute-1.3.1] startup
# [1.089s] [ext: omni.pip.cloud-1.1.3] startup
# [1.091s] [ext: omni.isaac.core_archive-2.3.0] startup
# [1.091s] [ext: omni.isaac.ml_archive-2.0.1] startup
# [1.091s] [ext: omni.mtlx-0.1.0] startup
# [1.091s] [ext: omni.usd.config-1.0.3] startup
# [1.094s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.095s] [ext: omni.usd.libs-1.0.0] startup
# [1.189s] [ext: omni.kit.telemetry-0.5.0] startup
# [1.210s] [ext: omni.kit.loop-isaac-1.2.0] startup
# [1.211s] [ext: omni.kit.test-0.0.0] startup
# [1.250s] [ext: omni.appwindow-1.1.8] startup
# [1.283s] [ext: omni.kit.renderer.core-1.0.1] startup
# [1.778s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.780s] [ext: omni.kit.renderer.imgui-1.0.1] startup
# [1.889s] [ext: omni.ui-2.23.11] startup
# [1.896s] [ext: omni.kit.mainwindow-1.0.3] startup
# [1.896s] [ext: carb.audio-0.1.0] startup
# [1.920s] [ext: omni.uiaudio-1.0.0] startup
# [1.921s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.921s] [ext: omni.usd.schema.forcefield-106.0.16] startup
# [2.025s] [ext: omni.usd.schema.scene.visualization-2.0.2] startup
# [2.026s] [ext: omni.usd.schema.audio-0.0.0] startup
# [2.028s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [2.033s] [ext: omni.usd.schema.anim-0.0.0] startup
# [2.045s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [2.050s] [ext: omni.usd.schema.physx-106.0.16] startup
# [2.069s] [ext: omni.anim.navigation.schema-106.0.2] startup
# [2.071s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [2.074s] [ext: omni.anim.graph.schema-106.0.2] startup
# [2.079s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [2.081s] [ext: omni.usd.schema.isaac-2.0.2] startup
# [2.085s] [ext: omni.kit.window.popup_dialog-2.0.24] startup
# [2.088s] [ext: omni.graph.exec-0.9.3] startup
# [2.088s] [ext: omni.kit.widget.nucleus_connector-1.1.5] startup
# [2.089s] [ext: omni.kit.usd_undo-0.1.8] startup
# [2.090s] [ext: omni.kit.exec.core-0.13.0] startup
# [2.091s] [ext: omni.usd_resolver-1.0.0] startup
# [2.094s] [ext: omni.resourcemonitor-105.0.1] startup
# [2.095s] [ext: omni.kit.actions.core-1.0.0] startup
# [2.096s] [ext: omni.activity.core-1.0.1] startup
# [2.097s] [ext: omni.usd.core-1.2.11] startup
# [2.100s] [ext: omni.timeline-1.0.10] startup
# [2.101s] [ext: omni.kit.commands-1.4.9] startup
# [2.103s] [ext: usdrt.scenegraph-7.4.8] startup
# [2.132s] [ext: omni.kit.audiodeviceenum-1.0.1] startup
# [2.133s] [ext: omni.hydra.usdrt_delegate-7.4.7] startup
# [2.148s] [ext: omni.hydra.scene_delegate-0.3.3] startup
# [2.152s] [ext: omni.usd-1.10.39] startup
# [2.176s] [ext: omni.kit.widget.nucleus_info-1.0.2] startup
# [2.176s] [ext: omni.kit.notification_manager-1.0.8] startup
# [2.178s] [ext: omni.kit.clipboard-1.0.3] startup
# [2.178s] [ext: omni.kit.widget.path_field-2.0.9] startup
# [2.179s] [ext: omni.kit.helper.file_utils-0.1.7] startup
# [2.180s] [ext: omni.kit.search_core-1.0.5] startup
# [2.180s] [ext: omni.kit.widget.context_menu-1.2.1] startup
# [2.181s] [ext: omni.kit.widget.browser_bar-2.0.9] startup
# [2.181s] [ext: omni.kit.widget.filebrowser-2.3.47] startup
# [2.184s] [ext: omni.kit.collaboration.telemetry-1.0.0] startup
# [2.185s] [ext: omni.kit.widget.options_menu-1.1.4] startup
# [2.186s] [ext: omni.kit.widget.search_delegate-1.0.4] startup
# [2.187s] [ext: omni.ui.scene-1.9.3] startup
# [2.190s] [ext: omni.kit.widget.options_button-1.0.2] startup
# [2.191s] [ext: omni.iray.libs-0.0.0] startup
# [2.195s] [ext: omni.ujitso.processor.texture-1.0.0] startup
# [2.195s] [ext: omni.kit.window.filepicker-2.10.32] startup
# [2.203s] [ext: omni.kit.collaboration.channel_manager-1.0.11] startup
# [2.203s] [ext: omni.mdl.neuraylib-0.2.4] startup
# [2.204s] [ext: omni.ujitso.client-0.0.0] startup
# [2.204s] [ext: omni.mdl-52.0.1] startup
# [2.215s] [ext: omni.kit.window.file_importer-1.1.11] startup
# [2.217s] [ext: omni.kit.usd.layers-2.1.30] startup
# [2.222s] [ext: omni.volume-0.5.0] startup
# [2.224s] [ext: omni.kit.menu.utils-1.5.23] startup
# [2.232s] [ext: omni.kit.context_menu-1.8.0] startup
# [2.233s] [ext: omni.hydra.rtx-0.2.0] startup
# [2.243s] [ext: omni.kit.material.library-1.4.0] startup
# [2.245s] [ext: omni.hydra.engine.stats-1.0.1] startup
# [2.248s] [ext: omni.kit.widget.searchable_combobox-1.0.5] startup
# [2.248s] [ext: omni.kit.viewport.registry-104.0.6] startup
# [2.248s] [ext: omni.kit.raycast.query-1.0.5] startup
# [2.253s] [ext: omni.kit.primitive.mesh-1.0.16] startup
# [2.256s] [ext: omni.kit.widget.settings-1.1.0] startup
# [2.257s] [ext: omni.kit.widget.prompt-1.0.7] startup
# [2.258s] [ext: omni.kit.collaboration.presence_layer-1.0.8] startup
# [2.259s] [ext: omni.kit.hotkeys.core-1.3.3] startup
# [2.259s] [ext: omni.kit.window.preferences-1.5.1] startup
# [2.267s] [ext: omni.kit.widget.live_session_management.ui-1.0.1] startup
# [2.268s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [2.268s] [ext: omni.kit.hydra_texture-1.2.6] startup
# [2.272s] [ext: omni.kit.window.file_exporter-1.0.29] startup
# [2.272s] [ext: omni.kit.widget.filter-1.1.3] startup
# [2.273s] [ext: omni.kit.widget.viewport-106.0.2] startup
# [2.275s] [ext: omni.kit.widget.stage-2.10.26] startup
# [2.281s] [ext: omni.kit.widget.live_session_management-1.2.18] startup
# [2.282s] [ext: omni.kit.viewport.window-106.0.8] startup
# [2.296s] [ext: omni.kit.stage_template.core-1.1.20] startup
# [2.297s] [ext: omni.graph.tools-1.77.0] startup
# [2.310s] [ext: omni.kit.window.cursor-1.1.2] startup
# [2.310s] [ext: omni.kit.viewport.utility-1.0.17] startup
# [2.311s] [ext: omni.kit.stage_templates-1.2.2] startup
# [2.312s] [ext: omni.kit.window.content_browser_registry-0.0.4] startup
# [2.312s] [ext: omni.kit.viewport.menubar.core-107.0.0] startup
# [2.320s] [ext: omni.kit.viewport.actions-105.2.8] startup
# [2.323s] [ext: omni.kit.window.file-1.3.52] startup
# [2.325s] [ext: omni.kit.widget.highlight_label-1.0.1] startup
# [2.325s] [ext: omni.inspect-1.0.1] startup
# [2.327s] [ext: omni.kit.window.content_browser-2.9.13] startup
# [2.336s] [ext: omni.kit.viewport.menubar.display-106.0.0] startup
# [2.337s] [ext: omni.kit.widget.graph-1.12.6] startup
# [2.340s] [ext: omni.usdphysics-106.0.16] startup
# [2.342s] [ext: omni.debugdraw-0.1.3] startup
# [2.345s] [ext: omni.kit.widget.searchfield-1.1.5] startup
# [2.345s] [ext: omni.kit.window.extensions-1.4.7] startup
# [2.348s] [ext: omni.usdphysics.ui-106.0.16] startup
# [2.365s] [ext: omni.kit.window.property-1.11.1] startup
# [2.367s] [ext: omni.graph.core-2.170.0] startup
# [2.369s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [2.370s] [ext: omni.kit.property.usd-3.21.26] startup
# [2.375s] [ext: omni.graph-1.135.0] startup
# [2.457s] [ext: omni.kvdb-106.0.16] startup
# [2.461s] [ext: omni.graph.ui-1.67.1] startup
# [2.478s] [ext: omni.graph.action_core-1.1.4] startup
# [2.483s] [ext: omni.localcache-106.0.16] startup
# [2.484s] [ext: omni.graph.action_nodes-1.21.3] startup
# [2.490s] [ext: omni.physx.foundation-106.0.16] startup
# [2.492s] [ext: omni.convexdecomposition-106.0.16] startup
# [2.496s] [ext: omni.graph.action-1.101.1] startup
# [2.497s] [ext: omni.physx.cooking-106.0.16] startup
# [2.506s] [ext: omni.kit.widget.toolbar-1.6.2] startup
# [2.517s] [ext: omni.kit.manipulator.transform-104.7.5] startup
# [2.530s] [ext: omni.physx-106.0.16] startup
# [2.547s] [ext: omni.kit.manipulator.tool.snap-1.4.5] startup
# [2.552s] [ext: omni.physx.stageupdate-106.0.16] startup
# [2.554s] [ext: omni.physx.commands-106.0.16] startup
# [2.557s] [ext: omni.ui_query-1.1.2] startup
# [2.558s] [ext: omni.graph.image.core-0.3.2] startup
# [2.561s] [ext: omni.physx.ui-106.0.16] startup
# [2.581s] [ext: omni.kit.ui_test-1.2.18] startup
# [2.583s] [ext: omni.graph.image.nodes-1.0.2] startup
# [2.584s] [ext: omni.physx.demos-106.0.16] startup
# [2.596s] [ext: omni.graph.ui_nodes-1.24.1] startup
# [2.600s] [ext: omni.graph.nodes-1.141.2] startup
# [2.610s] [ext: omni.physx.cct-106.0.16] startup
# [2.622s] [ext: omni.graph.bundle.action-2.0.4] startup
# [2.623s] [ext: omni.command.usd-1.0.3] startup
# [2.624s] [ext: omni.kit.numpy.common-0.1.2] startup
# [2.628s] [ext: omni.kit.property.material-1.9.3] startup
# [2.637s] [ext: omni.physx.graph-106.0.16] startup
# [2.658s] [ext: omni.kit.manipulator.selector-1.1.1] startup
# [2.672s] [ext: omni.isaac.dynamic_control-1.3.7] startup
# [2.686s] [ext: omni.kit.property.physx-106.0.16] startup
# [2.782s] [ext: omni.isaac.version-1.1.0] startup
# [2.784s] [ext: omni.kit.manipulator.viewport-107.0.0] startup
# [2.790s] [ext: omni.kit.viewport.manipulator.transform-106.0.0] startup
# ViewportTransformManipulatorExt on_startup
# [2.798s] [ext: omni.physics.tensors-106.0.16] startup
# [2.809s] [ext: omni.physx.vehicle-106.0.16] startup
# [2.834s] [ext: omni.isaac.nucleus-0.1.2] startup
# [2.835s] [ext: omni.fabric.commands-1.1.4] startup
# [2.840s] [ext: omni.kit.manipulator.prim.core-106.0.2] startup
# [2.895s] [ext: omni.physx.tensors-106.0.16] startup
# [2.900s] [ext: omni.warp.core-1.1.0] startup
# Warp 1.1.0 initialized:
#    CUDA Toolkit 11.5, Driver 12.2
#    Devices:
#      "cpu"      : "x86_64"
#      "cuda:0"   : "NVIDIA GeForce RTX 4090" (24 GiB, sm_89, mempool enabled)
#    Kernel cache:
#      /home/jianheng/.cache/warp/1.1.0
# [3.034s] [ext: omni.kit.graph.delegate.default-1.2.2] startup
# [3.036s] [ext: omni.graph.visualization.nodes-2.1.1] startup
# [3.043s] [ext: omni.kit.manipulator.prim.fabric-106.0.1] startup
# [3.045s] [ext: omni.kit.manipulator.prim.usd-106.0.1] startup
# [3.047s] [ext: omni.isaac.core-3.12.0] startup
# [3.924s] [ext: omni.kit.graph.editor.core-1.5.3] startup
# [3.927s] [ext: omni.kit.graph.usd.commands-1.3.1] startup
# [3.928s] [ext: omni.kit.widget.material_preview-1.0.16] startup
# [3.930s] [ext: omni.kit.manipulator.prim-106.0.0] startup
# [3.930s] [ext: omni.kit.manipulator.selection-104.0.9] startup
# [3.931s] [ext: omni.kit.window.toolbar-1.6.1] startup
# [3.933s] [ext: omni.kit.widget.layers-1.7.9] startup
# [3.944s] [ext: omni.kit.window.material_graph-1.8.15] startup
# [3.964s] [ext: omni.graph.scriptnode-1.18.2] startup
# [3.967s] [ext: omni.kit.graph.delegate.modern-1.10.6] startup
# [3.970s] [ext: omni.sensors.tiled-0.0.3] startup
# [3.974s] [ext: omni.physx.supportui-106.0.16] startup
# [3.985s] [ext: omni.physx.telemetry-106.0.16] startup
# [3.988s] [ext: omni.physx.camera-106.0.16] startup
# [3.996s] [ext: omni.isaac.ui-0.15.1] startup
# [4.000s] [ext: omni.warp-1.1.0] startup
# [4.006s] [ext: omni.syntheticdata-0.6.7] startup
# [4.020s] [ext: omni.physx.bundle-106.0.16] startup
# [4.021s] [ext: omni.isaac.utils-1.0.1] startup
# [4.023s] [ext: omni.replicator.core-1.11.8] startup
# 2024-07-09 13:10:08 [4,072ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [4.175s] [ext: omni.isaac.lula-3.0.1] startup
# [4.185s] [ext: omni.isaac.surface_gripper-1.0.1] startup
# [4.189s] [ext: omni.isaac.core_nodes-1.15.4] startup
# [4.204s] [ext: omni.isaac.cloner-0.8.1] startup
# [4.208s] [ext: omni.isaac.motion_generation-7.0.1] startup
# [4.223s] [ext: omni.isaac.manipulators-2.1.0] startup
# [4.228s] [ext: omni.kit.graph.widget.variables-2.1.0] startup
# [4.232s] [ext: omni.isaac.gym-0.11.3] startup
# [4.233s] [ext: omni.isaac.dofbot-0.3.2] startup
# [4.235s] [ext: omni.graph.window.core-1.107.1] startup
# [4.261s] [ext: omni.importer.mjcf-1.1.0] startup
# [4.276s] [ext: omni.isaac.menu-0.4.1] startup
# [4.286s] [ext: omni.graph.window.generic-1.23.1] startup
# [4.298s] [ext: omni.graph.window.action-1.25.2] startup
# [4.308s] [ext: omni.kit.actions.window-1.1.1] startup
# [4.317s] [ext: omni.kit.viewport.menubar.lighting-106.0.2] startup
# [4.326s] [ext: omni.isaac.wheeled_robots-2.1.3] startup
# [4.339s] [ext: omni.kit.ui.actions-1.0.1] startup
# [4.346s] [ext: omni.kit.hotkeys.window-1.4.5] startup
# [4.365s] [ext: omni.kit.selection-0.1.4] startup
# [4.370s] [ext: omni.kit.manipulator.camera-105.0.5] startup
# [4.376s] [ext: omni.kit.menu.common-1.1.5] startup
# [4.379s] [ext: omni.isaac.kit-1.10.0] startup
# [4.380s] [ext: omni.kit.menu.edit-1.1.19] startup
# [4.388s] [ext: omni.kit.menu.file-1.1.9] startup
# [4.394s] [ext: omni.isaac.franka-0.4.1] startup
# [4.396s] [ext: omni.kit.widget.stage_icons-1.0.3] startup
# [4.401s] [ext: omni.kit.profiler.window-2.2.1] startup
# 2024-07-09 13:10:09 [4,449ms] [Warning] [omni.kit.profiler.window] remove _SpanInstance.__lt__ and use insort 'key' arg instead
# [4.566s] [ext: omni.kit.property.audio-1.0.11] startup
# [4.569s] [ext: omni.isaac.cortex-0.3.8] startup
# [4.570s] [ext: omni.kit.window.stage-2.5.9] startup
# [4.575s] [ext: omni.kit.property.geometry-1.3.0] startup
# [4.578s] [ext: omni.kit.property.camera-1.0.6] startup
# [4.579s] [ext: omni.sensors.nv.common-1.0.1] startup
# [4.589s] [ext: omni.kit.menu.stage-1.2.5] startup
# [4.590s] [ext: omni.isaac.debug_draw-0.7.1] startup
# [4.595s] [ext: omni.sensors.nv.wpm-1.0.0] startup
# [4.596s] [ext: omni.sensors.nv.materials-1.0.0] startup
# [4.599s] [ext: omni.isaac.range_sensor-3.0.1] startup
# [4.608s] [ext: omni.hydra.scene_api-0.1.2] startup
# [4.614s] [ext: omni.sensors.nv.radar-1.0.1] startup
# [4.618s] [ext: omni.sensors.nv.lidar-1.0.1] startup
# [4.622s] [ext: omni.kit.property.render-1.1.1] startup
# [4.623s] [ext: omni.kit.property.transform-1.5.1] startup
# [4.626s] [ext: omni.kit.property.light-1.0.8] startup
# [4.628s] [ext: omni.isaac.sensor-11.3.0] startup
# [4.678s] [ext: omni.isaac.block_world-1.0.0] startup
# [4.683s] [ext: omni.kit.property.bundle-1.2.11] startup
# [4.686s] [ext: omni.kit.property.isaac-0.2.3] startup
# [4.690s] [ext: omni.isaac.quadruped-1.4.5] startup
# [4.705s] [ext: omni.isaac.occupancy_map-1.0.1] startup
# [4.717s] [ext: omni.rtx.window.settings-0.6.15] startup
# [4.723s] [ext: omni.kit.widget.live-2.1.6] startup
# [4.725s] [ext: omni.kit.widget.calendar-1.0.8] startup
# [4.727s] [ext: omni.kit.property.layer-1.1.5] startup
# [4.729s] [ext: omni.kit.viewport.menubar.render-106.1.2] startup
# [4.732s] [ext: omni.kit.viewport.menubar.settings-106.0.0] startup
# [4.736s] [ext: omni.kit.viewport.rtx-104.0.1] startup
# [4.737s] [ext: omni.kit.widget.cache_indicator-2.0.8] startup
# [4.738s] [ext: omni.kit.widget.extended_searchfield-1.0.27] startup
# [4.747s] [ext: omni.kit.widget.timeline-105.0.1] startup
# [4.750s] [ext: omni.kit.window.commands-0.2.5] startup
# [4.753s] [ext: omni.kit.window.console-0.2.12] startup
# [4.763s] [ext: omni.kit.window.script_editor-1.7.6] startup
# [4.765s] [ext: omni.kit.menu.create-1.0.12] startup
# [4.767s] [ext: omni.kit.window.status_bar-0.1.6] startup
# [4.771s] [ext: omni.kit.window.title-1.1.3] startup
# [4.772s] [ext: omni.replicator.isaac-1.15.0] startup
# [4.783s] [ext: omni.replicator.replicator_yaml-2.0.5] startup
# [4.802s] [ext: omni.rtx.settings.core-0.6.0] startup
# [4.808s] [ext: omni.kit.stage_column.payload-2.0.0] startup
# [4.811s] [ext: omni.isaac.scene_blox-0.1.1] startup
# [4.813s] [ext: omni.kit.stage_column.variant-1.0.13] startup
# [4.820s] [ext: semantics.schema.editor-0.3.4] startup
# [4.827s] [ext: semantics.schema.property-1.0.2] startup
# [4.831s] [ext: omni.kit.viewport.menubar.camera-105.1.8] startup
# [4.839s] [ext: omni.isaac.universal_robots-0.3.5] startup
# [4.841s] [ext: omni.isaac.cortex.sample_behaviors-1.0.5] startup
# [4.846s] [ext: omni.importer.urdf-1.14.1] startup
# [4.885s] [ext: omni.kit.window.stats-0.1.6] startup
# [4.892s] [ext: omni.isaac.sim.python-4.0.0] startup
# [4.894s] Simulation App Starting
# [6.860s] app ready
# [7.890s] Simulation App Startup Complete
# CONFIG
# ├── algo
# │   └── name: dreamer_v3
# │       total_steps: 500000
# │       per_rank_batch_size: 8
# │       run_test: true
# │       cnn_keys:
# │         encoder:
# │         - local_map
# │         - rgb_image
# │         decoder:
# │         - local_map
# │       mlp_keys:
# │         encoder:
# │         - position
# │         decoder:
# │         - position
# │       world_model:
# │         optimizer:
# │           _target_: torch.optim.Adam
# │           lr: 0.0001
# │           eps: 1.0e-08
# │           weight_decay: 0
# │           betas:
# │           - 0.9
# │           - 0.999
# │         discrete_size: 32
# │         stochastic_size: 32
# │         kl_dynamic: 0.5
# │         kl_representation: 0.1
# │         kl_free_nats: 1.0
# │         kl_regularizer: 1.0
# │         continue_scale_factor: 1.0
# │         clip_gradients: 1000.0
# │         decoupled_rssm: false
# │         learnable_initial_recurrent_state: true
# │         encoder:
# │           cnn_channels_multiplier: 32
# │           cnn_act: torch.nn.SiLU
# │           dense_act: torch.nn.SiLU
# │           mlp_layers: 2
# │           cnn_layer_norm:
# │             cls: sheeprl.models.models.LayerNormChannelLast
# │             kw:
# │               eps: 0.001
# │           mlp_layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │           dense_units: 512
# │         recurrent_model:
# │           recurrent_state_size: 512
# │           layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │           dense_units: 512
# │         transition_model:
# │           hidden_size: 512
# │           dense_act: torch.nn.SiLU
# │           layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │         representation_model:
# │           hidden_size: 512
# │           dense_act: torch.nn.SiLU
# │           layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │         observation_model:
# │           cnn_channels_multiplier: 32
# │           cnn_act: torch.nn.SiLU
# │           dense_act: torch.nn.SiLU
# │           mlp_layers: 2
# │           cnn_layer_norm:
# │             cls: sheeprl.models.models.LayerNormChannelLast
# │             kw:
# │               eps: 0.001
# │           mlp_layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │           dense_units: 512
# │         reward_model:
# │           dense_act: torch.nn.SiLU
# │           mlp_layers: 2
# │           layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │           dense_units: 512
# │           bins: 255
# │         discount_model:
# │           learnable: true
# │           dense_act: torch.nn.SiLU
# │           mlp_layers: 2
# │           layer_norm:
# │             cls: sheeprl.models.models.LayerNorm
# │             kw:
# │               eps: 0.001
# │           dense_units: 512
# │       actor:
# │         optimizer:
# │           _target_: torch.optim.Adam
# │           lr: 8.0e-05
# │           eps: 1.0e-05
# │           weight_decay: 0
# │           betas:
# │           - 0.9
# │           - 0.999
# │         cls: sheeprl.algos.dreamer_v3.agent.Actor
# │         ent_coef: 0.0003
# │         min_std: 0.1
# │         max_std: 1.0
# │         init_std: 2.0
# │         dense_act: torch.nn.SiLU
# │         mlp_layers: 2
# │         layer_norm:
# │           cls: sheeprl.models.models.LayerNorm
# │           kw:
# │             eps: 0.001
# │         dense_units: 512
# │         clip_gradients: 100.0
# │         unimix: 0.01
# │         action_clip: 1.0
# │         moments:
# │           decay: 0.99
# │           max: 1.0
# │           percentile:
# │             low: 0.05
# │             high: 0.95
# │       critic:
# │         optimizer:
# │           _target_: torch.optim.Adam
# │           lr: 8.0e-05
# │           eps: 1.0e-05
# │           weight_decay: 0
# │           betas:
# │           - 0.9
# │           - 0.999
# │         dense_act: torch.nn.SiLU
# │         mlp_layers: 2
# │         layer_norm:
# │           cls: sheeprl.models.models.LayerNorm
# │           kw:
# │             eps: 0.001
# │         dense_units: 512
# │         per_rank_target_network_update_freq: 1
# │         tau: 0.02
# │         bins: 255
# │         clip_gradients: 100.0
# │       gamma: 0.996996996996997
# │       lmbda: 0.95
# │       horizon: 15
# │       replay_ratio: 0.5
# │       learning_starts: 1000
# │       per_rank_pretrain_steps: 0
# │       per_rank_sequence_length: 64
# │       cnn_layer_norm:
# │         cls: sheeprl.models.models.LayerNormChannelLast
# │         kw:
# │           eps: 0.001
# │       mlp_layer_norm:
# │         cls: sheeprl.models.models.LayerNorm
# │         kw:
# │           eps: 0.001
# │       dense_units: 512
# │       mlp_layers: 2
# │       dense_act: torch.nn.SiLU
# │       cnn_act: torch.nn.SiLU
# │       unimix: 0.01
# │       hafner_initialization: true
# │       player:
# │         discrete_size: 32
# │
# ├── buffer
# │   └── size: 500000
# │       memmap: true
# │       validate_args: false
# │       from_numpy: false
# │       checkpoint: true
# │
# ├── checkpoint
# │   └── every: 1000
# │       resume_from: null
# │       save_last: true
# │       keep_last: 5
# │
# ├── env
# │   └── id: isaac_sim_environment
# │       num_envs: 1
# │       frame_stack: 1
# │       sync_env: true
# │       screen_size: 64
# │       action_repeat: 1
# │       grayscale: false
# │       clip_rewards: false
# │       capture_video: true
# │       frame_stack_dilation: 1
# │       max_episode_steps: -1
# │       reward_as_observation: false
# │       wrapper:
# │         _target_: sheeprl.envs.isaacsim.IsaacSimWrapper
# │         map_size:
# │         - 84
# │         - 84
# │         rgb_size:
# │         - 84
# │         - 84
# │         seed: null
# │
# ├── fabric
# │   └── _target_: lightning.fabric.Fabric
# │       devices: 1
# │       num_nodes: 1
# │       strategy: auto
# │       accelerator: cuda
# │       precision: bf16-mixed
# │       callbacks:
# │       - _target_: sheeprl.utils.callback.CheckpointCallback
# │         keep_last: 5
# │
# └── metric
#     └── log_every: 1000
#         disable_timer: false
#         log_level: 0
#         sync_on_compute: false
#         aggregator:
#           _target_: sheeprl.utils.metric.MetricAggregator
#           raise_on_missing: false
#           metrics:
#             Rewards/rew_avg:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Game/ep_len_avg:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/world_model_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/value_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/policy_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/observation_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/reward_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/state_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Loss/continue_loss:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             State/kl:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             State/post_entropy:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             State/prior_entropy:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Grads/world_model:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Grads/actor:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#             Grads/critic:
#               _target_: torchmetrics.MeanMetric
#               sync_on_compute: false
#         logger:
#           _target_: lightning.fabric.loggers.TensorBoardLogger
#           name: 2024-07-09_14-10-14_dreamer_v3_isaac_sim_environment_5
#           root_dir: logs/runs/dreamer_v3/isaac_sim_environment
#           version: null
#           default_hp_metric: true
#           prefix: ''
#           sub_dir: null
#
# [2024-07-09 14:10:14,826][pytorch_lightning.utilities.rank_zero][INFO] - Using bfloat16 Automatic Mixed Precision (AMP)
# INFO: Seed set to 5
# [2024-07-09 14:10:14,842][lightning.fabric.utilities.seed][INFO] - Seed set to 5
# Log dir: logs/runs/dreamer_v3/isaac_sim_environment/2024-07-09_14-10-14_dreamer_v3_isaac_sim_environment_5/version_0
# Error executing job with overrides: ['exp=dreamer_v3_isaacsim']
# Traceback (most recent call last):
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/sheeprl/sheeprl/cli.py", line 352, in run
#     run_algorithm(cfg)
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/sheeprl/sheeprl/cli.py", line 190, in run_algorithm
#     fabric.launch(reproducible(command), cfg, **kwargs)
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/kit/python/lib/python3.10/site-packages/lightning/fabric/fabric.py", line 845, in launch
#     return self._wrap_and_launch(function, self, *args, **kwargs)
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/kit/python/lib/python3.10/site-packages/lightning/fabric/fabric.py", line 931, in _wrap_and_launch
#     return to_run(*args, **kwargs)
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/kit/python/lib/python3.10/site-packages/lightning/fabric/fabric.py", line 936, in _wrap_with_setup
#     return to_run(*args, **kwargs)
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/sheeprl/sheeprl/cli.py", line 186, in wrapper
#     return func(fabric, cfg, *args, **kwargs)
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/sheeprl/sheeprl/algos/dreamer_v3/dreamer_v3.py", line 770, in main
#     imagined_observations = imagine(
# TypeError: imagine() missing 1 required positional argument: 'horizon'
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.
# 2024-07-09 13:10:16 [11,463ms] [Warning] [carb] [Plugin: omni.sensors.tiled.plugin] Module /home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/extscache/omni.sensors.tiled-0.0.3+106.0.0.lx64.r/bin/libomni.sensors.tiled.plugin.so remained loaded after unload request
# 2024-07-09 13:10:16 [11,467ms] [Warning] [carb] [Plugin: omni.spectree.delegate.plugin] Module /home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/kit/exts/omni.usd_resolver/bin/libomni.spectree.delegate.plugin.so remained loaded after unload request
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Annotators' for removal
# 2024-07-09 13:10:16 [11,469ms] [Warning] [omni.graph.core.plugin] Could not find category 'Replicator:Core' for removal
# 2024-07-09 13:10:16 [11,603ms] [Warning] [carb] Recursive unloadAllPlugins() detected!
