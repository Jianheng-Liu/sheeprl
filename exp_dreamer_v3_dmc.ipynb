# %% [markdown]
# ## Check obsevation space:

# %%
from dm_control import suite
# Iterate over a task set:
for domain_name , task_name in suite.BENCHMARKING: 
    print('domain name: ', domain_name, '\n')
    print('task name: ', task_name, '\n')
# Out:
# domain name:  acrobot
#
# task name:  swingup
#
# domain name:  acrobot
#
# task name:  swingup_sparse
#
# domain name:  ball_in_cup
#
# task name:  catch
#
# domain name:  cartpole
#
# task name:  balance
#
# domain name:  cartpole
#
# task name:  balance_sparse
#
# domain name:  cartpole
#
# task name:  swingup
#
# domain name:  cartpole
#
# task name:  swingup_sparse
#
# domain name:  cheetah
#
# task name:  run
#
# domain name:  finger
#
# task name:  spin
#
# domain name:  finger
#
# task name:  turn_easy
#
# domain name:  finger
#
# task name:  turn_hard
#
# domain name:  fish
#
# task name:  upright
#
# domain name:  fish
#
# task name:  swim
#
# domain name:  hopper
#
# task name:  stand
#
# domain name:  hopper
#
# task name:  hop
#
# domain name:  humanoid
#
# task name:  stand
#
# domain name:  humanoid
#
# task name:  walk
#
# domain name:  humanoid
#
# task name:  run
#
# domain name:  manipulator
#
# task name:  bring_ball
#
# domain name:  pendulum
#
# ...

# %%
# !HYDRA_FULL_ERROR=1 python examples/observation_space.py agent=dreamer_v3 env=dmc env.wrapper.domain_name=pendulum env.wrapper.task_name=swingup env.grayscale=True algo.cnn_keys.encoder=[rgb] algo.mlp_keys.encoder=[state]
# Out:
# [2024-07-03 11:01:07,815][absl][INFO] - MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# [2024-07-03 11:01:07,870][absl][INFO] - Successfully imported OpenGL backend: glfw
# [2024-07-03 11:01:07,957][absl][INFO] - MuJoCo library version is: 3.1.6
# Error executing job with overrides: ['agent=dreamer_v3', 'env=dmc', 'env.wrapper.domain_name=pendulum', 'env.wrapper.task_name=swingup', 'env.grayscale=True', 'algo.cnn_keys.encoder=[rgb]', 'algo.mlp_keys.encoder=[state]']
# Traceback (most recent call last):
#   File "/home/jianheng/.local/share/ov/pkg/isaac-sim-4.0.0/sheeprl/examples/observation_space.py", line 42, in <module>
#     main()
#   File "/home/jianheng/miniconda3/envs/isaac-sim/lib/python3.10/site-packages/hydra/main.py", line 90, in decorated_main
#     _run_hydra(
#   File "/home/jianheng/miniconda3/envs/isaac-sim/lib/python3.10/site-packages/hydra/_internal/utils.py", line 394, in _run_hydra
#     _run_app(
# ...

# %% [markdown]
# ## Experiments

# %% [markdown]
# 1. Using grascale image as observation

# %%
# !python sheeprl.py exp=dreamer_v3_dmc_walk_walk_grayscale
# Out:
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/lightning/fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/pkg_resources/__init__.py:2350: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# ...

# %% [markdown]
# 2. Using grascale image and vector values as observation

# %%
# !python sheeprl.py exp=dreamer_v3_dmc_walk_walk_grayscale_vector
# Out:
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/lightning/fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/pkg_resources/__init__.py:2350: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# ...

# %% [markdown]
# 3. Using vector values as observation

# %%
# !python sheeprl.py exp=dreamer_v3_dmc_walk_walk_vector
# Out:
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/lightning/fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/pkg_resources/__init__.py:2350: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# ...

# %%
# !tensorboard --logdir logs
# Out:
# TensorFlow installation not found - running with reduced feature set.
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.16.2 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C
