# %% [markdown]
# # Observation Size Experiments

# %%
from dm_control import suite
# Iterate over a task set:
for domain_name , task_name in suite.BENCHMARKING: 
    print('domain name: ', domain_name, '\n')
    print('task name: ', task_name, '\n')
# Out:
# domain name:  acrobot
#
# task name:  swingup
#
# domain name:  acrobot
#
# task name:  swingup_sparse
#
# domain name:  ball_in_cup
#
# task name:  catch
#
# domain name:  cartpole
#
# task name:  balance
#
# domain name:  cartpole
#
# task name:  balance_sparse
#
# domain name:  cartpole
#
# task name:  swingup
#
# domain name:  cartpole
#
# task name:  swingup_sparse
#
# domain name:  cheetah
#
# task name:  run
#
# domain name:  finger
#
# task name:  spin
#
# domain name:  finger
#
# task name:  turn_easy
#
# domain name:  finger
#
# task name:  turn_hard
#
# domain name:  fish
#
# task name:  upright
#
# domain name:  fish
#
# task name:  swim
#
# domain name:  hopper
#
# task name:  stand
#
# domain name:  hopper
#
# task name:  hop
#
# domain name:  humanoid
#
# task name:  stand
#
# domain name:  humanoid
#
# task name:  walk
#
# domain name:  humanoid
#
# task name:  run
#
# domain name:  manipulator
#
# task name:  bring_ball
#
# domain name:  pendulum
#
# ...

# %% [markdown]
# ## Input Size: 128
# Map Size: 128\*128\*1
#
# Camera Size: 64\*64\*1

# %%
# !python examples/observation_space.py agent=dreamer_v3 env=dmc_128 env.wrapper.domain_name=walker env.wrapper.task_name=walk env.grayscale=True algo.cnn_keys.encoder=[rgb] algo.mlp_keys.encoder=[state]
# Out:
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/lightning_utilities/core/imports.py:13: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   import pkg_resources
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/lightning/fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/pkg_resources/__init__.py:2317: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# ...

# %%
# !python sheeprl.py exp=dreamer_v3_dmc_walker_walk_128
# Out:
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/lightning/fabric/__init__.py:41: Deprecated call to `pkg_resources.declare_namespace('lightning.fabric')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# /home/jianheng/miniconda3/envs/sheeprl/lib/python3.10/site-packages/pkg_resources/__init__.py:2317: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('lightning')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(parent)
# ...
